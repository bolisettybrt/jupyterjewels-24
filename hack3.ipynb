# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\gknag\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\gknag\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gknag\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gknag\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gknag\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\gknag\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\gknag\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\gknag\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in c:\users\gknag\anaconda3\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\gknag\anaconda3\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gknag\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gknag\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\gknag\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplot
# Out:
# Collecting matplot
#   Downloading matplot-0.1.9-py2.py3-none-any.whl.metadata (241 bytes)
# Collecting pyloco>=0.0.134 (from matplot)
#   Downloading pyloco-0.0.139-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=3.1.1 in c:\users\gknag\anaconda3\lib\site-packages (from matplot) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gknag\anaconda3\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.8.2)
# Collecting ushlex (from pyloco>=0.0.134->matplot)
#   Downloading ushlex-0.99.1.tar.gz (4.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: websocket-client in c:\users\gknag\anaconda3\lib\site-packages (from pyloco>=0.0.134->matplot) (0.58.0)
# Collecting twine (from pyloco>=0.0.134->matplot)
#   Downloading twine-5.0.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing (from pyloco>=0.0.134->matplot)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#      -------------- ----------------------- 30.7/78.6 kB 640.0 kB/s eta 0:00:01
#      ---------------------------------------- 78.6/78.6 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting SimpleWebSocketServer (from pyloco>=0.0.134->matplot)
#   Downloading SimpleWebSocketServer-0.1.2.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six>=1.5 in c:\users\gknag\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.16.0)
# Requirement already satisfied: pkginfo>=1.8.1 in c:\users\gknag\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.9.6)
# Collecting readme-renderer>=35.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading readme_renderer-43.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests>=2.20 in c:\users\gknag\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.31.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in c:\users\gknag\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\gknag\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.7)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\gknag\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (7.0.1)
# Requirement already satisfied: keyring>=15.1 in c:\users\gknag\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (23.13.1)
# Collecting rfc3986>=1.4.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: rich>=12.0.0 in c:\users\gknag\anaconda3\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (13.3.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\gknag\anaconda3\lib\site-packages (from importlib-metadata>=3.6->twine->pyloco>=0.0.134->matplot) (3.17.0)
# Requirement already satisfied: jaraco.classes in c:\users\gknag\anaconda3\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (3.2.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\gknag\anaconda3\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (0.2.0)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading nh3-0.2.17-cp37-abi3-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: docutils>=0.13.1 in c:\users\gknag\anaconda3\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.18.1)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\gknag\anaconda3\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gknag\anaconda3\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gknag\anaconda3\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gknag\anaconda3\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\gknag\anaconda3\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gknag\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.0)
# Requirement already satisfied: more-itertools in c:\users\gknag\anaconda3\lib\site-packages (from jaraco.classes->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (10.1.0)
# Downloading matplot-0.1.9-py2.py3-none-any.whl (5.0 kB)
# Downloading pyloco-0.0.139-py2.py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.2 kB ? eta -:--:--
#    ---------------------------------------- 60.2/60.2 kB 3.1 MB/s eta 0:00:00
# Downloading twine-5.0.0-py3-none-any.whl (37 kB)
# Downloading readme_renderer-43.0-py3-none-any.whl (13 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading nh3-0.2.17-cp37-abi3-win_amd64.whl (571 kB)
#    ---------------------------------------- 0.0/571.5 kB ? eta -:--:--
#    --------------------------------------  563.2/571.5 kB 17.8 MB/s eta 0:00:01
#    --------------------------------------- 571.5/571.5 kB 11.9 MB/s eta 0:00:00
# Building wheels for collected packages: SimpleWebSocketServer, typing, ushlex
#   Building wheel for SimpleWebSocketServer (setup.py): started
#   Building wheel for SimpleWebSocketServer (setup.py): finished with status 'done'
#   Created wheel for SimpleWebSocketServer: filename=SimpleWebSocketServer-0.1.2-py3-none-any.whl size=9687 sha256=980a4c67634079e944afa7e505602f73a03f695caae1446f7defcea72af8916e
#   Stored in directory: c:\users\gknag\appdata\local\pip\cache\wheels\e7\4d\d6\386351cf1f926ad0e48873adcbaabf09bb05ff2d0b9ed2cc91
#   Building wheel for typing (setup.py): started
#   Building wheel for typing (setup.py): finished with status 'done'
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26325 sha256=71216b6d9bc3a7f64b9b88e5ef8a16fc572e7a7a9ed5a6b7fd6bfc2d82f3f0b4
#   Stored in directory: c:\users\gknag\appdata\local\pip\cache\wheels\9d\67\2f\53e3ef32ec48d11d7d60245255e2d71e908201d20c880c08ee
#   Building wheel for ushlex (setup.py): started
#   Building wheel for ushlex (setup.py): finished with status 'done'
#   Created wheel for ushlex: filename=ushlex-0.99.1-py3-none-any.whl size=4401 sha256=fb02502a03f9a0be4e00fa606bdd963a3114678105b8e4c38cb0c0c041214994
#   Stored in directory: c:\users\gknag\appdata\local\pip\cache\wheels\2e\48\44\fed44e2a0643b96307111dcd72be5ae027d04ebb671cc51e5d
# Successfully built SimpleWebSocketServer typing ushlex
# Installing collected packages: ushlex, SimpleWebSocketServer, nh3, typing, rfc3986, readme-renderer, twine, pyloco, matplot
# Successfully installed SimpleWebSocketServer-0.1.2 matplot-0.1.9 nh3-0.2.17 pyloco-0.0.139 readme-renderer-43.0 rfc3986-2.0.0 twine-5.0.0 typing-3.7.4.3 ushlex-0.99.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df=pd.read_excel("Cardiac_Outcomes.xlsx")

# %%
df
# Out:
#       inpatient_number DestinationDischarge admission_ward admission_way  \
# 0               857781                 Home     Cardiology  NonEmergency
# 1               743087                 Home     Cardiology  NonEmergency
# 2               866418                 Home     Cardiology  NonEmergency
# 3               775928                 Home     Cardiology     Emergency
# 4               810128                 Home     Cardiology  NonEmergency
# ...                ...                  ...            ...           ...
# 2003            740689   HealthcareFacility    GeneralWard     Emergency
# 2004            734280   HealthcareFacility    GeneralWard     Emergency
# 2005            781004   HealthcareFacility     Cardiology     Emergency
# 2006            744870              Unknown     Cardiology  NonEmergency
# 2007            791864                 Home     Cardiology     Emergency
#
#      discharge_department  visit_times respiratory_support oxygen_inhalation  \
# 0              Cardiology            1                 NaN     OxygenTherapy
# 1              Cardiology            1                 NaN     OxygenTherapy
# 2              Cardiology            2                 NaN     OxygenTherapy
# 3              Cardiology            1                 NaN     OxygenTherapy
# 4              Cardiology            1                 NaN     OxygenTherapy
# ...                   ...          ...                 ...               ...
# 2003          GeneralWard            1                 NaN     OxygenTherapy
# 2004          GeneralWard            1                 NaN     OxygenTherapy
# 2005           Cardiology            1                 NaN     OxygenTherapy
# 2006           Cardiology            1                 IMV     OxygenTherapy
# 2007           Cardiology            1                 NaN     OxygenTherapy
#
#       dischargeDay Admission_date  ... death_within_28_days  \
# 0               11     2017-01-24  ...                    0
# 1                8     2017-05-05  ...                    0
# 2                5     2016-11-18  ...                    0
# 3               11     2017-10-02  ...                    0
# 4                5     2019-11-17  ...                    0
# ...            ...            ...  ...                  ...
# 2003             5     2016-02-07  ...                    0
# 2004             8     2017-03-29  ...                    0
# 2005            14     2018-01-22  ...                    0
# 2006             1     2019-11-27  ...                    1
# 2007             6     2017-02-17  ...                    0
#
#       re_admission_within_28_days  death_within_3_months  \
# 0                               0                      0
# 1                               0                      0
# 2                               0                      0
# 3                               1                      0
# 4                               0                      0
# ...                           ...                    ...
# 2003                            0                      0
# 2004                            0                      0
# 2005                            0                      0
# 2006                            0                      1
# 2007                            0                      0
#
#       re_admission_within_3_months  death_within_6_months  \
# 0                                0                      0
# 1                                0                      0
# 2                                0                      0
# 3                                1                      0
# 4                                0                      0
# ...                            ...                    ...
# 2003                             0                      0
# 2004                             0                      0
# 2005                             1                      0
# 2006                             0                      1
# 2007                             0                      0
#
#       re_admission_within_6_months  time_of_death__days_from_admission  \
# 0                                0                                 NaN
# 1                                0                                 NaN
# 2                                0                                 NaN
# 3                                1                                 NaN
# 4                                0                                 NaN
# ...                            ...                                 ...
# 2003                             0                                 NaN
# 2004                             0                                 NaN
# 2005                             1                                 NaN
# 2006                             0                                 1.0
# 2007                             0                                 NaN
#
#       readmission_time_days_from_admission  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                     19.0
# 4                                      NaN
# ...                                    ...
# 2003                                   NaN
# 2004                                   NaN
# 2005                                  76.0
# 2006                                   NaN
# 2007                                   NaN
#
#       return_to_emergency_department_within_6_months  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                                1.0
# 4                                                0.0
# ...                                              ...
# 2003                                             0.0
# 2004                                             0.0
# 2005                                             1.0
# 2006                                             0.0
# 2007                                             0.0
#
#       time_to_emergency_department_within_6_months
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                             19.0
# 4                                              NaN
# ...                                            ...
# 2003                                           NaN
# 2004                                           NaN
# 2005                                          76.0
# 2006                                           NaN
# 2007                                           NaN
#
# [2008 rows x 21 columns]

# %%
import glob
glob.glob("Cardiac_Outcomes.xlsx")
# Out:
# ['Cardiac_Outcomes.xlsx']

# %%
response= pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name='PatientHistory')

# %%
card= pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name='CardiacComplications')

# %%
data_file=('Cardiac_Outcomes.xlsx')
all_sheets=pd.read_excel(data_file,sheet_name=None)
#to access sheet by name in excel
Hospital_data=all_sheets['Hospitalization_Discharge']
Cardiac_data=all_sheets['CardiacComplications']
Response_data=all_sheets['Responsivenes']
Patient_data=all_sheets['PatientHistory']
lab_data=all_sheets['Labs']
Demography_data=all_sheets['Demography']
Patientpre_data=all_sheets['Patient_Precriptions']

# %%
Hospital_data.head()
# Out:
#    inpatient_number DestinationDischarge admission_ward admission_way  \
# 0            857781                 Home     Cardiology  NonEmergency
# 1            743087                 Home     Cardiology  NonEmergency
# 2            866418                 Home     Cardiology  NonEmergency
# 3            775928                 Home     Cardiology     Emergency
# 4            810128                 Home     Cardiology  NonEmergency
#
#   discharge_department  visit_times respiratory_support oxygen_inhalation  \
# 0           Cardiology            1                 NaN     OxygenTherapy
# 1           Cardiology            1                 NaN     OxygenTherapy
# 2           Cardiology            2                 NaN     OxygenTherapy
# 3           Cardiology            1                 NaN     OxygenTherapy
# 4           Cardiology            1                 NaN     OxygenTherapy
#
#    dischargeDay Admission_date  ... death_within_28_days  \
# 0            11     2017-01-24  ...                    0
# 1             8     2017-05-05  ...                    0
# 2             5     2016-11-18  ...                    0
# 3            11     2017-10-02  ...                    0
# 4             5     2019-11-17  ...                    0
#
#    re_admission_within_28_days  death_within_3_months  \
# 0                            0                      0
# 1                            0                      0
# 2                            0                      0
# 3                            1                      0
# 4                            0                      0
#
#    re_admission_within_3_months  death_within_6_months  \
# 0                             0                      0
# 1                             0                      0
# 2                             0                      0
# 3                             1                      0
# 4                             0                      0
#
#    re_admission_within_6_months  time_of_death__days_from_admission  \
# 0                             0                                 NaN
# 1                             0                                 NaN
# 2                             0                                 NaN
# 3                             1                                 NaN
# 4                             0                                 NaN
#
#    readmission_time_days_from_admission  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                  19.0
# 4                                   NaN
#
#    return_to_emergency_department_within_6_months  \
# 0                                             0.0
# 1                                             0.0
# 2                                             0.0
# 3                                             1.0
# 4                                             0.0
#
#    time_to_emergency_department_within_6_months
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                          19.0
# 4                                           NaN
#
# [5 rows x 21 columns]

# %%
Hospital_data.tail()
# Out:
#       inpatient_number DestinationDischarge admission_ward admission_way  \
# 2003            740689   HealthcareFacility    GeneralWard     Emergency
# 2004            734280   HealthcareFacility    GeneralWard     Emergency
# 2005            781004   HealthcareFacility     Cardiology     Emergency
# 2006            744870              Unknown     Cardiology  NonEmergency
# 2007            791864                 Home     Cardiology     Emergency
#
#      discharge_department  visit_times respiratory_support oxygen_inhalation  \
# 2003          GeneralWard            1                 NaN     OxygenTherapy
# 2004          GeneralWard            1                 NaN     OxygenTherapy
# 2005           Cardiology            1                 NaN     OxygenTherapy
# 2006           Cardiology            1                 IMV     OxygenTherapy
# 2007           Cardiology            1                 NaN     OxygenTherapy
#
#       dischargeDay Admission_date  ... death_within_28_days  \
# 2003             5     2016-02-07  ...                    0
# 2004             8     2017-03-29  ...                    0
# 2005            14     2018-01-22  ...                    0
# 2006             1     2019-11-27  ...                    1
# 2007             6     2017-02-17  ...                    0
#
#       re_admission_within_28_days  death_within_3_months  \
# 2003                            0                      0
# 2004                            0                      0
# 2005                            0                      0
# 2006                            0                      1
# 2007                            0                      0
#
#       re_admission_within_3_months  death_within_6_months  \
# 2003                             0                      0
# 2004                             0                      0
# 2005                             1                      0
# 2006                             0                      1
# 2007                             0                      0
#
#       re_admission_within_6_months  time_of_death__days_from_admission  \
# 2003                             0                                 NaN
# 2004                             0                                 NaN
# 2005                             1                                 NaN
# 2006                             0                                 1.0
# 2007                             0                                 NaN
#
#       readmission_time_days_from_admission  \
# 2003                                   NaN
# 2004                                   NaN
# 2005                                  76.0
# 2006                                   NaN
# 2007                                   NaN
#
#       return_to_emergency_department_within_6_months  \
# 2003                                             0.0
# 2004                                             0.0
# 2005                                             1.0
# 2006                                             0.0
# 2007                                             0.0
#
#       time_to_emergency_department_within_6_months
# 2003                                           NaN
# 2004                                           NaN
# 2005                                          76.0
# 2006                                           NaN
# 2007                                           NaN
#
# [5 rows x 21 columns]

# %%
response4= pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name='Labs')

# %%
#15	"Display a pie chart of number of patients in each category listed
-death_within_28_days
-re_admission_within_28_days
-death_within_3_months 
-re_admission_within_3_months 
-death_within_6_months 
-re_admission_within_6_months
-return_to_emergency_department_within_6_months"

# %%
import pandas as pd
import matplotlib.pyplot as plt

response2= pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name='Hospitalization_Discharge')
#select_columns=response2[[]'death_within_28_days','re_admission_within_28_days','death_within_3_months','re_admission_within_3_months','death_within_6_months','re_admission_within_6_months','return_to_emergency_department_within_6_month']]
# Select specific columns from the DataFrame
selected_columns = response2[['death_within_28_days','re_admission_within_28_days', 
                              'death_within_3_months','re_admission_within_3_months', 
                              'death_within_6_months','re_admission_within_6_months', 
                              'return_to_emergency_department_within_6_months']].value_counts()
#catagories==['death_within_28_days'='a','re_admission_within_28_days'='b', 
                             #'death_within_3_months'='c','re_admission_within_3_months'='d', 
                             #'death_within_6_months','re_admission_within_6_months', 
                              #'return_to_emergency_department_within_6_months'='e']


#value_counts = selected_columns.apply(pd.Series.value_counts)

# Display the counts
print(selected_columns)

#new_df=response2[[selected_columns]]
plt.pie(selected_columns,autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Patients in Each Category')
plt.axis('equal') 
plt.show()
# Out:
# death_within_28_days  re_admission_within_28_days  death_within_3_months  re_admission_within_3_months  death_within_6_months  re_admission_within_6_months  return_to_emergency_department_within_6_months
# 0                     0                            0                      0                             0                      0                             0.0                                               1169
#                                                                           1                             0                      1                             1.0                                                356
#                                                                           0                             0                      1                             1.0                                                274
#                       1                            0                      1                             0                      1                             1.0                                                137
# 1                     0                            1                      0                             1                      0                             0.0                                                 37
# 0                     0                            0                      0                             1                      0                             0.0                                                 15
#                                                                                                         0                      0                             1.0                                                  5
#                                                    1                      0                             1                      0                             0.0                                                  5
#                                                    0                      0                             0                      1                             0.0                                                  4
#                       1                            0                      1                             0                      0                             1.0                                                  3
#                       0                            0                      1                             0                      1                             0.0                                                  2
# Name: count, dtype: int64

# %%
#14Find the list of patients whose DischargeDay is greater than the value given by the user

# %%
import pandas as pd



#no_of_days =  int(input(" hi enter day"))
#print('no_of_days')



#user_date = pd.to_date(user_input)

response2= pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name='Hospitalization_Discharge')

selected_patients =response2 [response2['dischargeDay'] >11]


print(selected_patients['inpatient_number'],selected_patients['dischargeDay'])
# Out:
# 7       787530
# 8       795420
# 13      744167
# 16      759947
# 17      825016
#          ...
# 1987    759370
# 1993    733199
# 1997    750447
# 1999    804209
# 2005    781004
# Name: inpatient_number, Length: 392, dtype: int64 7       27
# 8       20
# 13      22
# 16      16
# 17      14
#         ..
# 1987    28
# 1993    13
# 1997    29
# 1999    29
# 2005    14
# Name: dischargeDay, Length: 392, dtype: int64

# %%
#13	Create a bar chart between lengthofstay and body temperature, classified as: Hypothermia, within range or hyperthermia

# %%
import pandas as pd
import matplotlib as plt

# %%
#	12	If left ventricular end diastolic diameter has a normal range: 3.5 - 5.6 cm, how many patients fall outside that limit and
what is the MAP of most patients with this condition?

# %%
import pandas as pd 

response3= pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name='CardiacComplications')
response4= pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name='Labs') 


outside_range = response3[(response3['left_ventricular_end_diastolic_diameter_LV'] < 3.5) | (response3['left_ventricular_end_diastolic_diameter_LV'] > 5.6)]


print("No of patients out of range :",len(outside_range['inpatient_number'])) 
x=response4[response4['inpatient_number'].isin (outside_range['inpatient_number'])] # getting the data from labs for the above patients

map_cnt = x.value_counts(['map'])  # getting the map value and  patients in that range
print(map_cnt)
# Out:
# No of patients out of range : 1311
# map
# 96.666667     56
# 93.333333     49
# 83.333333     48
# 100.000000    42
# 86.666667     38
#               ..
# 60.000000      1
# 96.333333      1
# 95.666667      1
# 94.333333      1
# 181.333333     1
# Name: count, Length: 196, dtype: int64

# %%
	#Group the days to re-admission into bins and count how many patients were in each bin

# %%
import pandas as pd
from pandas import dataframes,series

response2= pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name='Hospitalization_Discharge')
selected_columns = response2[['re_admission_within_28_days','re_admission_within_3_months','re_admission_within_6_months',]].value_counts()
response2('days')=response2['selected_columns'].dt.days
selected_columns.groupby('days')
# Out:
#   Cell In[67], line 6
#     response2('days')=response2['selected_columns'].dt.days
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
#Combine admission_ward & admission_way and count the patients under the new group. Create a pie chart and explode the biggest wedge

# %%
import pandas as pd
import matplotlib.pyplot as plt

response2= pd.read_excel('Cardiac_Outcomes.xlsx', sheet_name='Hospitalization_Discharge')
selected_columns= response2[['admission_ward','admission_way']]
print(selected_columns)
df=pd.DataFrame(selected_columns)
df['combine']=df['admission_ward']+'-'+df['admission_way']
patients_counts = df['combine'].value_counts()
explode = (0.1 if i == patients_counts.idxmax() else 0 for i in patients_counts.index)
plt.figure(figsize=(8, 8))
plt.pie(patients_counts,labels=patients_counts(),autopct='%1.1f%%', startangle=140, explode=explode)
plt.title('Distribution of Patients in Combined Groups')
plt.axis('equal')

# Show the pie chart
plt.show()
# Out:
#      admission_ward admission_way
# 0        Cardiology  NonEmergency
# 1        Cardiology  NonEmergency
# 2        Cardiology  NonEmergency
# 3        Cardiology     Emergency
# 4        Cardiology  NonEmergency
# ...             ...           ...
# 2003    GeneralWard     Emergency
# 2004    GeneralWard     Emergency
# 2005     Cardiology     Emergency
# 2006     Cardiology  NonEmergency
# 2007     Cardiology     Emergency
#
# [2008 rows x 2 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 12
#      10 explode = (0.1 if i == patients_counts.idxmax() else 0 for i in patients_counts.index)
#      11 plt.figure(figsize=(8, 8))
# ---> 12 plt.pie(patients_counts,labels=patients_counts(),autopct='%1.1f%%', startangle=140, explode=explode)
#      13 plt.title('Distribution of Patients in Combined Groups')
#      14 plt.axis('equal')
#
# TypeError: 'Series' object is not callable
